# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shap
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import csr_matrix
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from collections import Counter
from imblearn.over_sampling import RandomOverSampler 
import seaborn as sns
from sklearn.metrics import roc_auc_score
from sklearn.metrics import cohen_kappa_score, make_scorer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, ConfusionMatrixDisplay, classification_report

# %%
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...                                       ...
# 6814                                 0.539468
# 6815                                 0.538269
# 6816                                 0.533744
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 0                                              0.405750
# 1                                              0.516730
# 2                                              0.472295
# 3                                              0.457733
# 4                                              0.522298
# ...                                                 ...
# 6814                                           0.543230
# 6815                                           0.524172
# 6816                                           0.520638
# 6817                                           0.554045
# 6818                                           0.549548
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 0                    0.601457                      0.601457
# 1                    0.610235                      0.610235
# 2                    0.601450                      0.601364
# 3                    0.583541                      0.583541
# 4                    0.598783                      0.598783
# ...                       ...                           ...
# 6814                 0.604455                      0.604462
# 6815                 0.598308                      0.598308
# 6816                 0.610444                      0.610213
# 6817                 0.607850                      0.607850
# 6818                 0.627409                      0.627409
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                   0.998969                    0.796887
# 1                   0.998946                    0.797380
# 2                   0.998857                    0.796403
# 3                   0.998700                    0.796967
# 4                   0.998973                    0.797366
# ...                      ...                         ...
# 6814                0.998992                    0.797409
# 6815                0.998992                    0.797414
# 6816                0.998984                    0.797401
# 6817                0.999074                    0.797500
# 6818                0.998080                    0.801987
#
#        After-tax net Interest Rate  \
# 0                         0.808809
# 1                         0.809301
# 2                         0.808388
# 3                         0.808966
# 4                         0.809304
# ...                            ...
# 6814                      0.809331
# 6815                      0.809327
# 6816                      0.809317
# 6817                      0.809399
# 6818                      0.813800
#
#        Non-industry income and expenditure/revenue  \
# 0                                         0.302646
# 1                                         0.303556
# 2                                         0.302035
# 3                                         0.303350
# 4                                         0.303475
# ...                                            ...
# 6814                                      0.303510
# 6815                                      0.303520
# 6816                                      0.303512
# 6817                                      0.303498
# 6818                                      0.313415
#
#        Continuous interest rate (after tax)   Operating Expense Rate  \
# 0                                  0.780985             1.256969e-04
# 1                                  0.781506             2.897851e-04
# 2                                  0.780284             2.361297e-04
# 3                                  0.781241             1.078888e-04
# 4                                  0.781550             7.890000e+09
# ...                                     ...                      ...
# 6814                               0.781588             1.510213e-04
# 6815                               0.781586             5.220000e+09
# 6816                               0.781546             2.509312e-04
# 6817                               0.781663             1.236154e-04
# 6818                               0.786079             1.431695e-03
#
#        Research and development expense rate   Cash flow rate  \
# 0                               0.000000e+00         0.458143
# 1                               0.000000e+00         0.461867
# 2                               2.550000e+07         0.458521
# 3                               0.000000e+00         0.465705
# 4                               0.000000e+00         0.462746
# ...                                      ...              ...
# 6814                            4.500000e+09         0.463734
# 6815                            1.440000e+09         0.461978
# 6816                            1.039086e-04         0.472189
# 6817                            2.510000e+09         0.476123
# 6818                            0.000000e+00         0.427721
#
#        Interest-bearing debt interest rate   Tax rate (A)  \
# 0                             7.250725e-04       0.000000
# 1                             6.470647e-04       0.000000
# 2                             7.900790e-04       0.000000
# 3                             4.490449e-04       0.000000
# 4                             6.860686e-04       0.000000
# ...                                    ...            ...
# 6814                          1.790179e-04       0.113372
# 6815                          2.370237e-04       0.371596
# 6816                          0.000000e+00       0.490839
# 6817                          2.110211e-04       0.181294
# 6818                          5.900000e+08       0.000000
#
#        Net Value Per Share (B)   Net Value Per Share (A)  \
# 0                     0.147950                  0.147950
# 1                     0.182251                  0.182251
# 2                     0.177911                  0.177911
# 3                     0.154187                  0.154187
# 4                     0.167502                  0.167502
# ...                        ...                       ...
# 6814                  0.175045                  0.175045
# 6815                  0.181324                  0.181324
# 6816                  0.269521                  0.269521
# 6817                  0.213392                  0.213392
# 6818                  0.220766                  0.220766
#
#        Net Value Per Share (C)   Persistent EPS in the Last Four Seasons  \
# 0                     0.147950                                  0.169141
# 1                     0.182251                                  0.208944
# 2                     0.193713                                  0.180581
# 3                     0.154187                                  0.193722
# 4                     0.167502                                  0.212537
# ...                        ...                                       ...
# 6814                  0.175045                                  0.216602
# 6815                  0.181324                                  0.216697
# 6816                  0.269521                                  0.210929
# 6817                  0.213392                                  0.228326
# 6818                  0.220766                                  0.227758
#
#        Cash Flow Per Share   Revenue Per Share (Yuan ¥)  \
# 0                 0.311664                     0.017560
# 1                 0.318137                     0.021144
# 2                 0.307102                     0.005944
# 3                 0.321674                     0.014368
# 4                 0.319162                     0.029690
# ...                    ...                          ...
# 6814              0.320966                     0.020766
# 6815              0.318278                     0.023050
# 6816              0.324857                     0.044255
# 6817              0.346573                     0.031535
# 6818              0.305793                     0.000665
#
#        Operating Profit Per Share (Yuan ¥)  \
# 0                                 0.095921
# 1                                 0.093722
# 2                                 0.092338
# 3                                 0.077762
# 4                                 0.096898
# ...                                    ...
# 6814                              0.098200
# 6815                              0.098608
# 6816                              0.100073
# 6817                              0.111799
# 6818                              0.092501
#
#        Per Share Net profit before tax (Yuan ¥)  \
# 0                                      0.138736
# 1                                      0.169918
# 2                                      0.142803
# 3                                      0.148603
# 4                                      0.168412
# ...                                         ...
# 6814                                   0.172102
# 6815                                   0.172780
# 6816                                   0.173232
# 6817                                   0.185584
# 6818                                   0.182119
#
#        Realized Sales Gross Profit Growth Rate   Operating Profit Growth Rate  \
# 0                                     0.022102                       0.848195
# 1                                     0.022080                       0.848088
# 2                                     0.022760                       0.848094
# 3                                     0.022046                       0.848005
# 4                                     0.022096                       0.848258
# ...                                        ...                            ...
# 6814                                  0.022374                       0.848205
# 6815                                  0.022159                       0.848245
# 6816                                  0.022068                       0.847978
# 6817                                  0.022350                       0.854064
# 6818                                  0.025316                       0.848053
#
#        After-tax Net Profit Growth Rate   Regular Net Profit Growth Rate  \
# 0                              0.688979                         0.688979
# 1                              0.689693                         0.689702
# 2                              0.689463                         0.689470
# 3                              0.689110                         0.689110
# 4                              0.689697                         0.689697
# ...                                 ...                              ...
# 6814                           0.689778                         0.689778
# 6815                           0.689734                         0.689734
# 6816                           0.689202                         0.689202
# 6817                           0.696113                         0.696113
# 6818                           0.689527                         0.689527
#
#        Continuous Net Profit Growth Rate   Total Asset Growth Rate  \
# 0                               0.217535              4.980000e+09
# 1                               0.217620              6.110000e+09
# 2                               0.217601              7.280000e+09
# 3                               0.217568              4.880000e+09
# 4                               0.217626              5.510000e+09
# ...                                  ...                       ...
# 6814                            0.217635              7.070000e+09
# 6815                            0.217631              5.220000e+09
# 6816                            0.217547              5.990000e+09
# 6817                            0.218006              7.250000e+09
# 6818                            0.217605              9.350000e+09
#
#        Net Value Growth Rate   Total Asset Return Growth Rate Ratio  \
# 0                   0.000327                               0.263100
# 1                   0.000443                               0.264516
# 2                   0.000396                               0.264184
# 3                   0.000382                               0.263371
# 4                   0.000439                               0.265218
# ...                      ...                                    ...
# 6814                0.000450                               0.264517
# 6815                0.000445                               0.264730
# 6816                0.000435                               0.263858
# 6817                0.000529                               0.264409
# 6818                0.000519                               0.264186
#
#        Cash Reinvestment %   Current Ratio   Quick Ratio  \
# 0                 0.363725        0.002259      0.001208
# 1                 0.376709        0.006016      0.004039
# 2                 0.368913        0.011543      0.005348
# 3                 0.384077        0.004194      0.002896
# 4                 0.379690        0.006022      0.003727
# ...                    ...             ...           ...
# 6814              0.380155        0.010451      0.005457
# 6815              0.377389        0.009259      0.006741
# 6816              0.379392        0.038424      0.035112
# 6817              0.401028        0.012782      0.007256
# 6818              0.360102        0.051348      0.040897
#
#        Interest Expense Ratio   Total debt/Total net worth   Debt ratio %  \
# 0                    0.629951                     0.021266       0.207576
# 1                    0.635172                     0.012502       0.171176
# 2                    0.629631                     0.021248       0.207516
# 6815                        0.112329                    0.642072
# 6816                        0.110933                    0.631678
# 6817                        0.110957                    0.684857
# 6818                        0.110933                    0.659917
#
#        Cash Flow to Liability   CFO to Assets   Cash Flow to Equity  \
# 0                    0.458609        0.520382              0.312905
# 1                    0.459001        0.567101              0.314163
# 2                    0.459254        0.538491              0.314515
# 3                    0.448518        0.604105              0.302382
# 4                    0.454411        0.578469              0.311567
# ...                       ...             ...                   ...
# 6814                 0.458639        0.587178              0.314063
# 6815                 0.459058        0.569498              0.314446
# 6816                 0.452465        0.589341              0.313353
# 6817                 0.471313        0.678338              0.320118
# 6818                 0.483285        0.505531              0.316238
#
#        Current Liability to Current Assets   Liability-Assets Flag  \
# 0                                 0.118250                       0
# 1                                 0.047775                       0
# 2                                 0.025346                       0
# 3                                 0.067250                       0
# 4                                 0.047725                       0
# ...                                    ...                     ...
# 6814                              0.027951                       0
# 6815                              0.031470                       0
# 6816                              0.007542                       0
# 6817                              0.022916                       0
# 6818                              0.005579                       0
#
#        Net Income to Total Assets   Total assets to GNP price  \
# 0                        0.716845                    0.009219
# 1                        0.795297                    0.008323
# 2                        0.774670                    0.040003
# 3                        0.739555                    0.003252
# 4                        0.795016                    0.003878
# ...                           ...                         ...
# 6814                     0.799927                    0.000466
# 6815                     0.799748                    0.001959
# 6816                     0.797778                    0.002840
# 6817                     0.811808                    0.002837
# 6818                     0.815956                    0.000707
#
#        No-credit Interval   Gross Profit to Sales  \
# 0                0.622879                0.601453
# 1                0.623652                0.610237
# 2                0.623841                0.601449
# 3                0.622929                0.583538
# 4                0.623521                0.598782
# ...                   ...                     ...
# 6814             0.623620                0.604455
# 6815             0.623931                0.598306
# 6816             0.624156                0.610441
# 6817             0.623957                0.607846
# 6818             0.626680                0.627408
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 0                                0.827890              0.290202
# 1                                0.839969              0.283846
# 2                                0.836774              0.290189
# 3                                0.834697              0.281721
# 4                                0.839973              0.278514
# ...                                   ...                   ...
# 6814                             0.840359              0.279606
# 6815                             0.840306              0.278132
# 6816                             0.840138              0.275789
# 6817                             0.841084              0.277547
# 6818                             0.841019              0.275114
#
#        Degree of Financial Leverage (DFL)  \
# 0                                0.026601
# 1                                0.264577
# 2                                0.026555
# 3                                0.026697
# 4                                0.024752
# ...                                   ...
# 6814                             0.027064
# 6815                             0.027009
# 6816                             0.026791
# 6817                             0.026822
# 6818                             0.026793
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                              0.564050                   1
# 1                                              0.570175                   1
# 2                                              0.563706                   1
# 3                                              0.564663                   1
# 4                                              0.575617                   1
# ...                                                 ...                 ...
# 6814                                           0.566193                   1
# 6815                                           0.566018                   1
# 6816                                           0.565158                   1
# 6817                                           0.565302                   1
# 6818                                           0.565167                   1
#
#        Equity to Liability
# 0                 0.016469
# 1                 0.020794
# 2                 0.016474
# 3                 0.023982
# 4                 0.035490
# ...                    ...
# 6814              0.029890
# 6815              0.038284
# 6816              0.097649
# 6817              0.044009
# 6818              0.233902
#
# [6819 rows x 96 columns]

# %%
df.drop([' Current Liability to Liability', ' Net Income Flag'], axis = 1, inplace= True)

# %%
df.shape
# Out:
# (6819, 94)

# %% [markdown]
# # Separating the dataset

# %%
X = df.drop(['Bankrupt?'], axis = 1)
y = df['Bankrupt?']

# %% [markdown]
# # Selecting features with the Variance Threshold Method

# %%
X1 = X.copy()

# %%
from sklearn.preprocessing import MinMaxScaler 
transformer = MinMaxScaler().fit(X1)
x_normalized = transformer.transform(X1)
X_norm = pd.DataFrame(x_normalized, columns= X1.columns)

# %%
from sklearn.feature_selection import VarianceThreshold

var_threshold = 0.01
sel = VarianceThreshold(threshold=(var_threshold))
sel = sel.fit(X_norm)
temp = sel.transform(X_norm)
VTM_df = pd.DataFrame(temp, columns=sel.get_feature_names_out())
print(X1.shape)
print(VTM_df.shape)
# Out:
# (6819, 93)
# (6819, 15)

# %%
VTM_df
# Out:
#        Operating Expense Rate   Research and development expense rate  \
# 0                1.258227e-14                            0.000000e+00
# 1                2.900751e-14                            0.000000e+00
# 2                2.363661e-14                            2.555110e-03
# 3                1.079968e-14                            0.000000e+00
# 4                7.897898e-01                            0.000000e+00
# ...                       ...                                     ...
# 6814             1.511724e-14                            4.509018e-01
# 6815             5.225225e-01                            1.442886e-01
# 6816             2.511824e-14                            1.041169e-14
# 6817             1.237392e-14                            2.515030e-01
# 6818             1.433129e-13                            0.000000e+00
#
#        Interest-bearing debt interest rate   Tax rate (A)  \
# 0                             7.323965e-13       0.000000
# 1                             6.536007e-13       0.000000
# 2                             7.980596e-13       0.000000
# 3                             4.535807e-13       0.000000
# 4                             6.929986e-13       0.000000
# ...                                    ...            ...
# 6814                          1.808262e-13       0.113372
# 6815                          2.394179e-13       0.371596
# 6816                          0.000000e+00       0.490839
# 6817                          2.131526e-13       0.181294
# 6818                          5.959596e-01       0.000000
#
#        Total Asset Growth Rate   Total Asset Turnover  \
# 0                     0.498498               0.086957
# 1                     0.611612               0.064468
# 2                     0.728729               0.014993
# 3                     0.488488               0.089955
# 4                     0.551552               0.175412
# ...                        ...                    ...
# 6814                  0.707708               0.103448
# 6815                  0.522523               0.103448
# 6816                  0.599600               0.106447
# 6817                  0.725726               0.109445
# 6818                  0.935936               0.002999
#
#        Inventory Turnover Rate (times)   Fixed Assets Turnover Frequency  \
# 0                         1.822749e-14                      1.166173e-14
# 1                         9.369369e-01                      7.197197e-02
# 2                         6.506507e-03                      2.652653e-01
# 3                         7.137137e-01                      9.159159e-01
# 4                         1.635310e-14                      2.938149e-14
# ...                                ...                               ...
# 6814                      4.034034e-03                      1.431212e-14
# 6815                      9.949950e-01                      6.058040e-14
# 6816                      2.800109e-14                      1.025323e-13
# 6817                      4.554555e-01                      2.332345e-14
# 6818                      1.911912e-03                      2.998730e-14
#
#        Quick Assets/Total Assets   Current Assets/Total Assets  \
# 0                       0.166673                      0.190643
# 1                       0.127236                      0.182419
# 2                       0.340201                      0.602806
# 3                       0.161575                      0.225815
# 4                       0.260330                      0.358380
# ...                          ...                           ...
# 6814                    0.312840                      0.578455
# 6815                    0.335085                      0.444043
# 6816                    0.476747                      0.496053
# 6817                    0.353624                      0.564439
# 6818                    0.527136                      0.505010
#
#        Cash/Total Assets   Current Liabilities/Liability  \
# 0               0.004094                        0.676269
# 1               0.014948                        0.308589
# 2               0.000991                        0.446027
# 3               0.018851                        0.615848
# 4               0.014161                        0.975007
# ...                  ...                             ...
# 6814            0.099481                        0.786888
# 6815            0.080337                        0.849898
# 6816            0.412885                        0.553964
# 6817            0.112238                        0.893241
# 6818            0.238147                        1.000000
#
#        Current Asset Turnover Rate   Quick Asset Turnover Rate  \
# 0                     7.010000e-02                6.550000e-01
# 1                     1.065198e-14                7.700000e-01
# 2                     1.791094e-13                1.022676e-13
# 3                     8.140000e-01                6.050000e-01
# 4                     6.680000e-01                5.050000e-01
# ...                            ...                         ...
# 6814                  2.294154e-14                1.244230e-14
# 6815                  1.517299e-14                1.173396e-14
# 6816                  1.762272e-14                1.749713e-14
# 6817                  2.135940e-14                1.351937e-14
# 6818                  7.863781e-13                8.238471e-13
#
#        Cash Turnover Rate
# 0            4.580000e-02
# 1            2.490000e-01
# 2            7.610000e-02
# 3            2.030000e-01
# 4            8.240000e-02
# ...                   ...
# 6814         1.077940e-14
# 6815         7.710000e-01
# 6816         4.074263e-14
# 6817         1.165392e-14
# 6818         9.505992e-13
#
# [6819 rows x 15 columns]

# %% [markdown]
# # Singular Value Decomposition on the variables selected by the variance threshold

# %% [markdown]
# scaler = StandardScaler()
# scaler.fit(VTM_df)
# scaler.transform(VTM_df)
# X_SVD = pd.DataFrame(scaler.transform(VTM_df), columns=VTM_df.columns)

# %% [markdown]
# pca = PCA(random_state=5)
# pca.fit(VTM_df)
#
# print(pca.explained_variance_ratio_)
#
# X_pca = pd.DataFrame(pca.transform(VTM_df)).iloc[:,0:10]

# %% [markdown]
# plt.rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# PC_values = np.arange(pca.n_components_) +1
# plt.plot(PC_values, pca.explained_variance_ratio_, 'o-', linewidth=1, color='blue')
# plt.title('Scree Plot')
# plt.xlabel('Principal Component')
# plt.ylabel('Variance Explained')
# plt.show()

# %% [markdown]
# variance_acc_temp = pd.Series(pca.explained_variance_ratio_.cumsum())
# print (variance_acc_temp)

# %% [markdown]
# plt.bar(range(len(variance_acc_temp)), variance_acc_temp, color='royalblue' )
# plt.grid(color='#95a5a6', linestyle='--', linewidth=0.2, axis='y' )
# plt.xticks(range(len(variance_acc_temp)))
# plt.xlabel('PCA')
# plt.ylabel('Expl_var_ratio_accum')
# plt.title('Accummulated explained variance ratio')
# plt.rcParams['figure.figsize'] = [15, 10]
#
#
# plt.show()

# %% [markdown]
# coefficients= pd.DataFrame(pca.components_)

# %% [markdown]
# coefficients

# %% [markdown]
# PCA0 = b00 * col0 + b01 * col1 + ....+ b085 * col95
# eigen_vector1 = (b00, b01, b02,...)
# eigen_value = vancianza

# %% [markdown]
# # Balancing the dataset: upsampling and downsampling

# %%
df_1 = pd.concat([VTM_df, y], axis=1)

# %%
y = df_1['Bankrupt?'].astype('int')
X = df_1.drop(['Bankrupt?'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state = 17)

# %%
TRAIN = pd.concat([X_train, y_train], axis=1)
TRAIN.shape
# Out:
# (5455, 16)

# %%
(TRAIN[TRAIN["Bankrupt?"]==1])
# Out:
#        Operating Expense Rate   Research and development expense rate  \
# 1868             3.683236e-14                            5.020040e-01
# 3                1.079968e-14                            0.000000e+00
# 6641             5.535536e-01                            0.000000e+00
# 233              1.033668e-14                            0.000000e+00
# 1445             9.869870e-01                            3.246493e-01
# ...                       ...                                     ...
# 1179             2.199293e-14                            0.000000e+00
# 1                2.900751e-14                            0.000000e+00
# 948              2.651884e-14                            1.090505e-14
# 2908             2.681980e-14                            1.002004e-01
# 2022             3.429739e-14                            0.000000e+00
#
#        Interest-bearing debt interest rate   Tax rate (A)  \
# 1868                          3.525605e-13       0.558761
# 3                             4.535807e-13       0.000000
# 6641                          2.788158e-13       0.000000
# 233                           7.465393e-13       0.000000
# 1445                          7.889678e-13       0.000000
# ...                                    ...            ...
# 1179                          7.142128e-13       0.000000
# 1                             6.536007e-13       0.000000
# 948                           3.505401e-13       0.000000
# 2908                          4.586317e-13       0.000000
# 2022                          4.303461e-13       0.000000
#
#        Total Asset Growth Rate   Total Asset Turnover  \
# 1868                  0.738739               0.088456
# 3                     0.488488               0.089955
# 6641                  0.025726               0.244378
# 233                   0.746747               0.041979
# 1445                  0.546547               0.094453
# ...                        ...                    ...
# 1179                  0.467467               0.077961
# 1                     0.611612               0.064468
# 948                   0.729730               0.112444
# 2908                  0.526527               0.151424
# 2022                  0.673674               0.089955
#
#        Inventory Turnover Rate (times)   Fixed Assets Turnover Frequency  \
# 1868                      1.429509e-13                      1.204035e-14
# 3                         7.137137e-01                      9.159159e-01
# 6641                      1.903080e-14                      9.730727e-14
# 233                       7.917918e-01                      3.253253e-01
# 1445                      5.695696e-01                      5.641550e-14
# ...                                ...                               ...
# 1179                      1.576018e-14                      7.117117e-01
# 1                         9.369369e-01                      7.197197e-02
# 948                       4.724725e-01                      2.832134e-14
# 2908                      1.256606e-14                      2.347491e-14
# 2022                      1.300597e-14                      6.886887e-01
#
#        Quick Assets/Total Assets   Current Assets/Total Assets  \
# 1868                    0.474841                      0.459619
# 3                       0.161575                      0.225815
# 6641                    0.465562                      0.739236
# 233                     0.077033                      0.138243
# 1445                    0.311743                      0.483895
# ...                          ...                           ...
# 1179                    0.106695                      0.156383
# 1                       0.127236                      0.182419
# 948                     0.463405                      0.663927
# 2908                    0.292874                      0.413661
# 2022                    0.195478                      0.239571
#
#        Cash/Total Assets   Current Liabilities/Liability  \
# 1868            0.100335                        0.919886
# 3               0.018851                        0.615848
# 6641            0.108758                        0.858173
# 233             0.011382                        0.375513
# 1445            0.050565                        0.815745
# ...                  ...                             ...
# 1179            0.000409                        0.517257
# 1               0.014948                        0.308589
# 948             0.047491                        0.909853
# 2908            0.060502                        0.859651
# 2022            0.007454                        0.690745
#
#        Current Asset Turnover Rate   Quick Asset Turnover Rate  \
# 1868                  2.165894e-14                2.304338e-14
# 3                     8.140000e-01                6.050000e-01
# 6641                  7.290000e-01                4.620000e-02
# 233                   1.394958e-14                8.040000e-01
# 1445                  1.877357e-14                1.225404e-14
# ...                            ...                         ...
# 1179                  6.230000e-01                4.450000e-01
# 1                     1.065198e-14                7.700000e-01
# 948                   2.485980e-14                1.758731e-14
# 2908                  9.170000e-01                6.670000e-01
# 2022                  1.007911e-14                8.590000e-01
#
#        Cash Turnover Rate  Bankrupt?
# 1868         1.292516e-14          1
# 3            2.030000e-01          1
# 6641         3.330000e-01          1
# 233          3.140000e-01          1
# 1445         5.420000e-01          1
# ...                   ...        ...
# 1179         5.020000e-03          1
# 1            2.490000e-01          1
# 948          4.840000e-01          1
# 2908         3.980000e-01          1
# 2022         9.090000e-02          1
#
# [176 rows x 16 columns]

# %% [markdown]
# ## Upsampling the minority class

# %%
upsample_indexes = np.random.choice(TRAIN[TRAIN["Bankrupt?"]==1].index, size = 400, replace=True).tolist()

# %%
upsample = TRAIN.loc[upsample_indexes,:]
upsample
# Out:
#        Operating Expense Rate   Research and development expense rate  \
# 1866             6.116116e-01                                0.155311
# 1359             9.409409e-01                                0.190381
# 1132             2.403017e-14                                0.015631
# 2148             1.084251e-13                                0.000000
# 2536             9.389389e-01                                0.423848
# ...                       ...                                     ...
# 1868             3.683236e-14                                0.502004
# 2536             9.389389e-01                                0.423848
# 2470             2.893806e-14                                0.000000
# 2097             1.512882e-14                                0.000000
# 2094             2.289579e-14                                0.000000
#
#        Interest-bearing debt interest rate   Tax rate (A)  \
# 1866                          1.424385e-13       0.000000
# 1359                          9.384777e-13       0.000000
# 1132                          5.051010e-13       0.000000
# 2148                          6.859272e-13       0.000000
# 2536                          7.233047e-13       0.000000
# ...                                    ...            ...
# 1868                          3.525605e-13       0.558761
# 2536                          7.233047e-13       0.000000
# 2470                          3.677135e-13       0.000000
# 2097                          7.455291e-13       0.000000
# 2094                          8.475595e-13       0.000000
#
#        Total Asset Growth Rate   Total Asset Turnover  \
# 1866                  0.607608               0.160420
# 1359                  0.630631               0.181409
# 1132                  0.578579               0.058471
# 2148                  0.623624               0.005997
# 2536                  0.675676               0.056972
# ...                        ...                    ...
# 1868                  0.738739               0.088456
# 2536                  0.675676               0.056972
# 2470                  0.412412               0.098951
# 2097                  0.326326               0.062969
# 2094                  0.523524               0.031484
#
#        Inventory Turnover Rate (times)   Fixed Assets Turnover Frequency  \
# 1866                      1.321636e-14                      8.700860e-14
# 1359                      6.746747e-01                      1.331254e-13
# 1132                      3.293293e-01                      5.455455e-01
# 2148                      7.647648e-03                      2.122122e-01
# 2536                      2.784808e-14                      8.858859e-01
# ...                                ...                               ...
# 1868                      1.429509e-13                      1.204035e-14
# 2536                      2.784808e-14                      8.858859e-01
# 2470                      1.911912e-03                      8.558559e-01
# 2097                      8.038038e-02                      6.913738e-14
# 2094                      5.165165e-02                      1.552373e-14
#
#        Quick Assets/Total Assets   Current Assets/Total Assets  \
# 1866                    0.615321                      0.741154
# 1359                    0.475026                      0.778845
# 1132                    0.131400                      0.314496
# 2148                    0.034349                      0.756234
# 2536                    0.402040                      0.413775
# ...                          ...                           ...
# 1868                    0.474841                      0.459619
# 2536                    0.402040                      0.413775
# 2470                    0.129527                      0.124091
# 2097                    0.174700                      0.869358
# 2094                    0.163251                      0.802564
#
#        Cash/Total Assets   Current Liabilities/Liability  \
# 1866            0.075123                        0.699973
# 1359            0.007935                        0.861300
# 1132            0.001007                        0.693463
# 2148            0.001297                        0.949824
# 2536            0.004529                        0.829814
# ...                  ...                             ...
# 1868            0.100335                        0.919886
# 2536            0.004529                        0.829814
# 2470            0.015737                        0.449042
# 2097            0.072483                        0.990644
# 2094            0.004988                        0.863704
#
#        Current Asset Turnover Rate   Quick Asset Turnover Rate  \
# 1866                  1.750754e-14                1.490577e-14
# 1359                  1.640772e-14                1.006167e-14
# 1132                  2.075159e-14                8.670000e-01
# 2148                  5.714266e-13                3.042359e-14
# 2536                  3.008071e-14                2.985591e-14
# ...                            ...                         ...
# 1868                  2.165894e-14                2.304338e-14
# 2536                  3.008071e-14                2.985591e-14
# 2470                  3.130000e-01                3.890000e-01
# 2097                  4.255447e-14                8.210000e-01
# 2094                  9.991951e-14                2.046614e-14
#
#        Cash Turnover Rate  Bankrupt?
# 1866         4.950000e-01          1
# 1359         4.690000e-02          1
# 1132         1.810000e-02          1
# 2148         2.530000e-01          1
# 2536         8.820000e-02          1
# ...                   ...        ...
# 1868         1.292516e-14          1
# 2536         8.820000e-02          1
# 2470         1.450000e-01          1
# 2097         9.460000e-01          1
# 2094         1.620000e-02          1
#
# [400 rows x 16 columns]

# %% [markdown]
# ## Clustering to downsize the majority class

# %%
No_bankrupcies =  TRAIN[(TRAIN['Bankrupt?'] == 0)]

# %%
kmeans = KMeans(n_clusters=7, random_state=1)
kmeans.fit(No_bankrupcies)
# Out:
# KMeans(n_clusters=7, random_state=1)

# %%
clusters = kmeans.predict(No_bankrupcies)

elem_in_cluster = pd.Series(clusters).value_counts().sort_index() # Number of values in each cluster
elem_in_cluster
# Out:
# 0     648
# 1     725
# 2    1178
# 3     609
# 4     752
# 5     661
# 6     706
# dtype: int64

# %%
clusters_weight = []
for j in range(len(elem_in_cluster)):
    weight = elem_in_cluster[j]/len(No_bankrupcies)
    clusters_weight.append(weight)

# %%
No_bankrupcies["cluster"] = clusters
No_bankrupcies
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        
#
#        Cash Turnover Rate  Bankrupt?  cluster
# 2542         6.540000e-02          0        2
# 1809         1.746463e-14          0        2
# 4322         5.090000e-01          0        4
# 3933         8.428286e-14          0        2
# 1784         4.340000e-01          0        6
# ...                   ...        ...      ...
# 1337         3.030000e-01          0        1
# 406          7.780000e-01          0        0
# 5510         8.550000e-02          0        2
# 2191         5.420000e-01          0        1
# 2671         5.075770e-14          0        5
#
# [5279 rows x 17 columns]

# %%
new_No_bankrupcies = pd.DataFrame(columns=No_bankrupcies.columns, dtype=float)
 
for cluster, weight in enumerate(clusters_weight):
    new_No_bankrupcies = pd.concat([new_No_bankrupcies, No_bankrupcies[No_bankrupcies["cluster"]==cluster].sample(round(400*weight))], axis=0)
    
new_No_bankrupcies.drop(columns=['cluster'], inplace=True)

# %%
final1_df = pd.concat([new_No_bankrupcies, upsample], axis=0)
final1_df = final1_df.sort_index()

# %%
final1_df.shape
# Out:
# (799, 16)

# %%
y_train = final1_df['Bankrupt?'].astype('int')
X_train = final1_df.drop(['Bankrupt?'], axis=1)

# %% [markdown]
# # Predicting with KNN

# %%
# entrenar distintos modelos con distintos valores de k
K = range(2, 14, 3)
accuracies = []
models = []

for k in K:
    knn = KNeighborsClassifier(n_neighbors=k, weights = 'uniform') 
    knn.fit(X_train, y_train)
    models.append(knn)
    ypred_train = knn.predict(X_train)
    accuracies.append(accuracy_score(y_train, ypred_train))
    print("The accuracy of the model n_neighbors={} is: {:.2f}".format(k, accuracy_score(y_train, ypred_train)))
    print("The kappa of the model n_neighbors={} is: {:.2f}".format(k, cohen_kappa_score(y_train, ypred_train)))
# Out:
# The accuracy of the model n_neighbors=2 is: 0.98
# The kappa of the model n_neighbors=2 is: 0.96
# The accuracy of the model n_neighbors=5 is: 0.83
# The kappa of the model n_neighbors=5 is: 0.66
# The accuracy of the model n_neighbors=8 is: 0.80
# The kappa of the model n_neighbors=8 is: 0.61
# The accuracy of the model n_neighbors=11 is: 0.74
# The kappa of the model n_neighbors=11 is: 0.49

# %% [markdown]
# import pickle
#
# pickel.dump(models[0],

# %%
K = range(2, 14, 3)
#accuracies = []

for i in range(len(models)):
    #knn = KNeighborsClassifier(n_neighbors=k) 
    knn = models[i]
    ypred_test = knn.predict(X_test)
    accuracies.append(accuracy_score(y_test, ypred_test))
    print("The accuracy of the model n_neighbors={} is: {:.2f}".format(list(K)[i], accuracy_score(y_test, ypred_test)))
    print("The kappa score of the model n_neighbors={} is: {:.2f}".format(list(K)[i],cohen_kappa_score(y_test, ypred_test)))
# Out:
# The accuracy of the model n_neighbors=2 is: 0.80
# The kappa score of the model n_neighbors=2 is: 0.06
# The accuracy of the model n_neighbors=5 is: 0.63
# The kappa score of the model n_neighbors=5 is: 0.07
# The accuracy of the model n_neighbors=8 is: 0.68
# The kappa score of the model n_neighbors=8 is: 0.07
# The accuracy of the model n_neighbors=11 is: 0.62
# The kappa score of the model n_neighbors=11 is: 0.06

# %%
knn = KNeighborsClassifier(n_neighbors=2) 
knn.fit(X_train, y_train)
ypred_train = knn.predict(X_train)
ypred_test = knn.predict(X_test)
display(y.value_counts())
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
display(confusion_matrix(ypred_train, y_train))
# Out:
# array([[399,  16],
#        [  0, 384]], dtype=int64)

# %%
display(confusion_matrix(ypred_test, y_test))
# Out:
# array([[1071,   27],
#        [ 249,   17]], dtype=int64)

# %% [markdown]
# # Random Forest

# %%
clf = RandomForestClassifier(max_depth=4,
                             min_samples_split=6,
                             min_samples_leaf =3,
                             max_samples=0.8, random_state=8)
                            
clf.fit(X_train, y_train)

print("The accuracy for the Random Forest in the TRAIN set is {:.2f}".format(clf.score(X_train, y_train)))
print("The accuracy for the Random Forest in the TEST set is {:.2f}".format(clf.score(X_test, y_test)))

y_pred = clf.predict(X_train)
display(pd.DataFrame(y_pred).value_counts())
display(y.value_counts())
display(confusion_matrix(y_train, y_pred))
display(cohen_kappa_score(y_train, y_pred))

y_pred = clf.predict(X_test)
display(pd.DataFrame(y_pred).value_counts())
display(y.value_counts())
display(confusion_matrix(y_test, y_pred))
display(cohen_kappa_score(y_test, y_pred))
# Out:
# The accuracy for the Random Forest in the TRAIN set is 0.86
# The accuracy for the Random Forest in the TEST set is 0.78
# 1    439
# 0    360
# dtype: int64
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64
# array([[325,  74],
#        [ 35, 365]], dtype=int64)
# 0.7271251813348122
# 0    1033
# 1     331
# dtype: int64
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64
# array([[1026,  294],
#        [   7,   37]], dtype=int64)
# 0.14886436194472308

# %%
##### from sklearn.model_selection import GridSearchCV

max_depth_choices= [2, 3, 5,7,9] 
min_samples_split_choices = [2,4,6,8,9]  
min_samples_leaf_choices = [1,3] 
max_samples=[0.8,0.5]
#n_jobs = [-1]

grid = {'max_depth': max_depth_choices,
        'min_samples_split': min_samples_split_choices,
        'min_samples_leaf': min_samples_leaf_choices,
        'max_samples':max_samples}

model = RandomForestClassifier()
grid_search = GridSearchCV(estimator = model, param_grid = grid, cv = 5) 
grid_search.fit(X_train, y_train)
grid_search.best_score_
# Out:
# 0.7835455974842767

# %%
grid_search.best_params_
# Out:
# {'max_depth': 3,
#  'max_samples': 0.5,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2}

# %%
clf = RandomForestClassifier(**grid_search.best_params_, random_state =8)
                          
clf.fit(X_train, y_train)

print("The accuracy for the Random Forest in the TRAIN set is {:.2f}".format(clf.score(X_train, y_train)))
print("The accuracy for the Random Forest in the TEST set is {:.2f}".format(clf.score(X_test, y_test)))

y_pred = clf.predict(X_train)
display(pd.DataFrame(y_pred).value_counts())
display(y.value_counts())
display(confusion_matrix(y_train, y_pred))
display(cohen_kappa_score(y_train, y_pred))

y_pred = clf.predict(X_test)
display(pd.DataFrame(y_pred).value_counts())
display(y.value_counts())
display(confusion_matrix(y_test, y_pred))
display(cohen_kappa_score(y_test, y_pred))
# Out:
# The accuracy for the Random Forest in the TRAIN set is 0.83
# The accuracy for the Random Forest in the TEST set is 0.76
# 1    426
# 0    373
# dtype: int64
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64
# array([[318,  81],
#        [ 55, 345]], dtype=int64)
# 0.659546203638141
# 0    1004
# 1     360
# dtype: int64
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64
# array([[996, 324],
#        [  8,  36]], dtype=int64)
# 0.12809217214503554

# %%
coh_kap = make_scorer(cohen_kappa_score)

grid1 = GridSearchCV(clf, grid, scoring=cohen_kappa_score, cv=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [88], in <cell line: 3>()
#       1 coh_kap = make_scorer(cohen_kappa_score)
# ----> 3 grid1 = GridSearchCV(clf, grid, scoring=cohen_kappa_score, cv=5)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV.__init__(self, estimator, param_grid, scoring, n_jobs, refit, cv, verbose, pre_dispatch, error_score, return_train_score)
#    1376 super().__init__(
#    1377     estimator=estimator,
#    1378     scoring=scoring,
#    (...)
#    1385     return_train_score=return_train_score,
#    1386 )
#    1387 self.param_grid = param_grid
# -> 1388 _check_param_grid(param_grid)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:328, in _check_param_grid(param_grid)
#     325 if hasattr(param_grid, "items"):
#     326     param_grid = [param_grid]
# --> 328 for p in param_grid:
#     329     for name, v in p.items():
#     330         if isinstance(v, np.ndarray) and v.ndim > 1:
#
# TypeError: 'GridSearchCV' object is not iterable

# %% [markdown]
# ## Feature Extraction-SHAP

# %%
explainer = shap.TreeExplainer(clf)
shap_values = explainer.shap_values(X)

# %%
#shap.dependence_plot(' Tax rate (A)', shap_values, X)

# %%
shap.summary_plot(shap_values, X)

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

# %%
xgb_cl = xgb.XGBClassifier()

# %%
xgb_cl.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
print("The accuracy for the XGB in the TRAIN set is {:.2f}".format(xgb_cl.score(X_train, y_train)))
print("The accuracy for the XGB in the TEST set is {:.2f}".format(xgb_cl.score(X_test, y_test)))

y_pred = pd.Series(xgb_cl.predict(X_train))
display(pd.DataFrame(y_pred).value_counts())
display(confusion_matrix(y_train, y_pred))
display(cohen_kappa_score(y_train, y_pred))

y_pred = pd.Series(xgb_cl.predict(X_test))
display(pd.DataFrame(y_pred).value_counts())
display(confusion_matrix(y_test, y_pred))
display(cohen_kappa_score(y_test, y_pred))
# Out:
# The accuracy for the XGB in the TRAIN set is 1.00
# The accuracy for the XGB in the TEST set is 0.85
# 1    400
# 0    399
# dtype: int64
# array([[399,   0],
#        [  0, 400]], dtype=int64)
# 1.0
# 0    1142
# 1     222
# dtype: int64
# array([[1126,  194],
#        [  16,   28]], dtype=int64)
# 0.16559856447064858

# %% [markdown]
# Learning_rate: also called eta, it specifies how quickly the model fits the residual errors by using additional base learners.typical values: 0.01–0.2
#
# Gamma, reg_alpha, reg_lambda: these 3 parameters specify the values for 3 types of regularization done by XGBoost - minimum loss reduction to create a new split, L1 reg on leaf weights, L2 reg leaf weights respectively.Typical values for gamma: 0 - 0.5 but highly dependent on the data. Typical values for reg_alpha and reg_lambda: 0 - 1 is a good starting point but again, depends on the data.
#
# Max_depth - how deep the tree's decision nodes can go. Must be a positive integer. typical values: 1–10
#
# Subsample - fraction of the training set that can be used to train each tree. If this value is low, it may lead to underfitting or if it is too high, it may lead to overfitting. typical values: 0.5–0.9
#
# Colsample_bytree- fraction of the features that can be used to train each tree. A large value means almost all features can be used to build the decision tree. typical values: 0.5–0.9
#
# The above are the main hyperparameters people often tune. It is perfectly OK if you don’t understand them all completely (like me) but you can refer to this post which gives a thorough overview of how each of the above parameters works and how to tune them.

# %%
param_grid = {
    "max_depth": [3, 4, 5, 7],
    "learning_rate": [0.01, 0.2],
    "gamma": [0, 0.5, 1],
    "reg_lambda": [0, 0.5, 1, 10],
    "scale_pos_weight": [1, 3, 5],
    "subsample": [0.8],
    "colsample_bytree": [0.5],
    "reg_alpha": [0, 0.5, 1, 10]
}

# %%
# Init classifier
xgb_cl = xgb.XGBClassifier(objective="binary:logistic")

# Init Grid Search
grid_cv = GridSearchCV(xgb_cl, param_grid, n_jobs=-1, cv=3, scoring="roc_auc")

# Fit
_ = grid_cv.fit(X_train, y_train)

# %%
grid_cv.best_score_
# Out:
# 0.8421104663802926

# %%
grid_cv.best_params_
# Out:
# {'colsample_bytree': 0.5,
#  'gamma': 0,
#  'learning_rate': 0.2,
#  'max_depth': 3,
#  'reg_alpha': 10,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'subsample': 0.8}

# %%
final_cl = xgb.XGBClassifier(
    **grid_cv.best_params_,
    objective="binary:logistic")
_ = final_cl.fit(X_train, y_train)
preds = final_cl.predict(X_test)

print("The accuracy for the XGB in the TRAIN set is {:.2f}".format(final_cl.score(X_train, y_train)))
print("The accuracy for the XGB in the TEST set is {:.2f}".format(final_cl.score(X_test, y_test)))

y_pred = pd.Series(final_cl.predict(X_train))
display(pd.DataFrame(y_pred).value_counts())
display(confusion_matrix(y_train, y_pred))
display(cohen_kappa_score(y_train, y_pred))

y_pred = pd.Series(final_cl.predict(X_test))
display(pd.DataFrame(y_pred).value_counts())
display(confusion_matrix(y_test, y_pred))
display(cohen_kappa_score(y_test, y_pred))
# Out:
# The accuracy for the XGB in the TRAIN set is 0.90
# The accuracy for the XGB in the TEST set is 0.80
# 1    432
# 0    367
# dtype: int64
# array([[343,  56],
#        [ 24, 376]], dtype=int64)
# 0.7997292961700422
# 0    1059
# 1     305
# dtype: int64
# array([[1050,  270],
#        [   9,   35]], dtype=int64)
# 0.15280634734058196

# %%
coh_kap = make_scorer(cohen_kappa_score)

grid = GridSearchCV(final_cl(), param_grid, scoring=cohen_kappa_score, cv=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [86], in <cell line: 3>()
#       1 coh_kap = make_scorer(cohen_kappa_score)
# ----> 3 grid = GridSearchCV(final_cl(), param_grid, scoring=cohen_kappa_score, cv=5)
#
# TypeError: 'XGBClassifier' object is not callable

# %% [markdown]
# ## Feature extraction-SHAP

# %%
explainer = shap.TreeExplainer(final_cl)
shap_values = explainer.shap_values(X)

# %%
shap.force_plot(explainer.expected_value, shap_values[0, :], X.iloc[0, :])

# %%
shap.dependence_plot(' Tax rate (A)', shap_values, X)

# %%
shap.summary_plot(shap_values, X)

# %% [markdown]
# # K-fold Cross validation

# %%
a = np.zeros(shape=(4, 12))

pd.DataFrame(a)

# %%
# Aplicamos CV-10 a todos los modelos para tner una mejor estimacion del accuracy y menor varianza
nfolds = 10
models = [knn, clf, xgb_cl]
cv_scores = np.zeros((len(models), nfolds))

for i, model in enumerate(models):
    scores = cross_val_score(model, X, y, scoring='roc', cv=nfolds)
    cv_scores[i] = scores
    
cv_df = pd.DataFrame(cv_scores, index=[models])
cv_df['mean_score'] = cv_df.mean(1)
cv_df['std_score'] = cv_df.std(1)
